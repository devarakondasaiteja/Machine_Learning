# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\Admin\\Downloads\\diabetes.csv")

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#load datasets
data.columns=['pregnant','glucose','bp','skinT','insulin','bmi','pedigree','age','label']

# %%
data.head()
# Out:
#    pregnant  glucose  bp  skinT  insulin   bmi  pedigree  age  label
# 0         6      148  72     35        0  33.6     0.627   50      1
# 1         1       85  66     29        0  26.6     0.351   31      0
# 2         8      183  64      0        0  23.3     0.672   32      1
# 3         1       89  66     23       94  28.1     0.167   21      0
# 4         0      137  40     35      168  43.1     2.288   33      1

# %%
data.shape
# Out:
# (768, 9)

# %%
data=data.iloc[:20,:]
data
# Out:
#     pregnant  glucose  bp  skinT  insulin   bmi  pedigree  age  label
# 0          6      148  72     35        0  33.6     0.627   50      1
# 1          1       85  66     29        0  26.6     0.351   31      0
# 2          8      183  64      0        0  23.3     0.672   32      1
# 3          1       89  66     23       94  28.1     0.167   21      0
# 4          0      137  40     35      168  43.1     2.288   33      1
# 5          5      116  74      0        0  25.6     0.201   30      0
# 6          3       78  50     32       88  31.0     0.248   26      1
# 7         10      115   0      0        0  35.3     0.134   29      0
# 8          2      197  70     45      543  30.5     0.158   53      1
# 9          8      125  96      0        0   0.0     0.232   54      1
# 10         4      110  92      0        0  37.6     0.191   30      0
# 11        10      168  74      0        0  38.0     0.537   34      1
# 12        10      139  80      0        0  27.1     1.441   57      0
# 13         1      189  60     23      846  30.1     0.398   59      1
# 14         5      166  72     19      175  25.8     0.587   51      1
# 15         7      100   0      0        0  30.0     0.484   32      1
# 16         0      118  84     47      230  45.8     0.551   31      1
# 17         7      107  74      0        0  29.6     0.254   31      1
# 18         1      103  30     38       83  43.3     0.183   33      0
# 19         1      115  70     30       96  34.6     0.529   32      1

# %%
data.shape
# Out:
# (20, 9)

# %%
data.isnull().sum()
# Out:
# pregnant    0
# glucose     0
# bp          0
# skinT       0
# insulin     0
# bmi         0
# pedigree    0
# age         0
# label       0
# dtype: int64

# %%
data.isnull().sum().any()
# Out:
# False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pregnant  20 non-null     int64
#  1   glucose   20 non-null     int64
#  2   bp        20 non-null     int64
#  3   skinT     20 non-null     int64
#  4   insulin   20 non-null     int64
#  5   bmi       20 non-null     float64
#  6   pedigree  20 non-null     float64
#  7   age       20 non-null     int64
#  8   label     20 non-null     int64
# dtypes: float64(2), int64(7)
# memory usage: 1.5 KB

# %%
data.corr()
# Out:
#           pregnant   glucose        bp     skinT   insulin       bmi  \
# pregnant  1.000000  0.181410 -0.058186 -0.806660 -0.486759 -0.386041
# glucose   0.181410  1.000000  0.219686  0.016168  0.553790 -0.072565
# bp       -0.058186  0.219686  1.000000  0.008259  0.036305 -0.314031
# skinT    -0.806660  0.016168  0.008259  1.000000  0.461601  0.450973
# insulin  -0.486759  0.553790  0.036305  0.461601  1.000000  0.118807
# bmi      -0.386041 -0.072565 -0.314031  0.450973  0.118807  1.000000
# pedigree -0.039599  0.209934 -0.041423  0.103832 -0.023130  0.236690
# age       0.182946  0.667874  0.308379  0.043219  0.491582 -0.383225
# label    -0.015099  0.452664  0.098262  0.209843  0.316934 -0.077424
#
#           pedigree       age     label
# pregnant -0.039599  0.182946 -0.015099
# glucose   0.209934  0.667874  0.452664
# bp       -0.041423  0.308379  0.098262
# skinT     0.103832  0.043219  0.209843
# insulin  -0.023130  0.491582  0.316934
# bmi       0.236690 -0.383225 -0.077424
# pedigree  1.000000  0.174482  0.191270
# age       0.174482  1.000000  0.289022
# label     0.191270  0.289022  1.000000

# %%
#x=data.iloc[:,[0,1,2,3,4,5,6,7]]
#y=data.iloc[:,8]

# %%
# Feature engineering

# %%
feature_columns=['pregnant','glucose','bp','skinT','insulin','bmi','pedigree','age'] 
x=data[feature_columns] # Features
y=data.label  # target values

# %%
x
# Out:
#     pregnant  glucose  bp  skinT  insulin   bmi  pedigree  age
# 0          6      148  72     35        0  33.6     0.627   50
# 1          1       85  66     29        0  26.6     0.351   31
# 2          8      183  64      0        0  23.3     0.672   32
# 3          1       89  66     23       94  28.1     0.167   21
# 4          0      137  40     35      168  43.1     2.288   33
# 5          5      116  74      0        0  25.6     0.201   30
# 6          3       78  50     32       88  31.0     0.248   26
# 7         10      115   0      0        0  35.3     0.134   29
# 8          2      197  70     45      543  30.5     0.158   53
# 9          8      125  96      0        0   0.0     0.232   54
# 10         4      110  92      0        0  37.6     0.191   30
# 11        10      168  74      0        0  38.0     0.537   34
# 12        10      139  80      0        0  27.1     1.441   57
# 13         1      189  60     23      846  30.1     0.398   59
# 14         5      166  72     19      175  25.8     0.587   51
# 15         7      100   0      0        0  30.0     0.484   32
# 16         0      118  84     47      230  45.8     0.551   31
# 17         7      107  74      0        0  29.6     0.254   31
# 18         1      103  30     38       83  43.3     0.183   33
# 19         1      115  70     30       96  34.6     0.529   32

# %%
y
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    0
# 11    1
# 12    0
# 13    1
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    1
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1)

# %%
# create decision tree classifier object

from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
clf=clf.fit(x_train,y_train)

# %%
#predict the response for the dataset

y_pred=clf.predict(x_test)

# %%
# Model Accuracy ,how often the classifier is correct

from sklearn.metrics import accuracy_score,confusion_matrix
print("Accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 1.0

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1, 0],
#        [0, 1]], dtype=int64)

# %%
# installation for Graphiz

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\programdata\anaconda3\lib\site-packages (0.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in c:\programdata\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\programdata\anaconda3\lib\site-packages (from pydotplus) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # FOR WINDOWS GRAPHIZ

# %%
import os
os.environ["PATH"]+=os.pathsep+'C:\ProgramData\Anaconda3\bin'

# %%
data
# Out:
#     pregnant  glucose  bp  skinT  insulin   bmi  pedigree  age  label
# 0          6      148  72     35        0  33.6     0.627   50      1
# 1          1       85  66     29        0  26.6     0.351   31      0
# 2          8      183  64      0        0  23.3     0.672   32      1
# 3          1       89  66     23       94  28.1     0.167   21      0
# 4          0      137  40     35      168  43.1     2.288   33      1
# 5          5      116  74      0        0  25.6     0.201   30      0
# 6          3       78  50     32       88  31.0     0.248   26      1
# 7         10      115   0      0        0  35.3     0.134   29      0
# 8          2      197  70     45      543  30.5     0.158   53      1
# 9          8      125  96      0        0   0.0     0.232   54      1
# 10         4      110  92      0        0  37.6     0.191   30      0
# 11        10      168  74      0        0  38.0     0.537   34      1
# 12        10      139  80      0        0  27.1     1.441   57      0
# 13         1      189  60     23      846  30.1     0.398   59      1
# 14         5      166  72     19      175  25.8     0.587   51      1
# 15         7      100   0      0        0  30.0     0.484   32      1
# 16         0      118  84     47      230  45.8     0.551   31      1
# 17         7      107  74      0        0  29.6     0.254   31      1
# 18         1      103  30     38       83  43.3     0.183   33      0
# 19         1      115  70     30       96  34.6     0.529   32      1

# %% [raw]
# from sklearn.tree import export_graphviz
# from six import StringIO
# from IPython.display import Image
# import pydotplus
#
# dot_data = StringIO()
# export_graphviz(clf, out_file=dot_data,
# filled=True, rounded=True,
# special_characters=True,feature_names = feature_columns,class_names=['0','1'])
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# graph.write_png('diabetes.png')
# Image(graph.create_png())

# %%
from sklearn import tree
plt.figure(figsize=(12,10))
tree.plot_tree(clf,filled=True)  ## KNCD
# Out:
# [Text(334.8, 475.65000000000003, 'X[6] <= 0.216\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(167.4, 339.75, 'X[1] <= 156.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(83.7, 203.85000000000002, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(251.10000000000002, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(502.20000000000005, 339.75, 'X[5] <= 28.35\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(418.5, 203.85000000000002, 'X[5] <= 26.2\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(334.8, 67.94999999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(502.20000000000005, 67.94999999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(585.9, 203.85000000000002, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]')]

# %%
print(tree.export_text(clf))
# Out:
# |--- feature_1 <= 85.50
# |   |--- feature_0 <= 5.50
# |   |   |--- class: 0
# |   |--- feature_0 >  5.50
# |   |   |--- feature_6 <= 1.03
# |   |   |   |--- class: 1
# |   |   |--- feature_6 >  1.03
# |   |   |   |--- class: 0
# |--- feature_1 >  85.50
# |   |--- class: 1

# %%
pimax=x_train
pimax['label']=y_train
# Out:
# <ipython-input-31-d17fb0ff990e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pimax['label']=y_train

# %%
pimax.shape
# Out:
# (18, 9)

# %%
pimax
# Out:
#     pregnant  glucose  bp  skinT  insulin   bmi  pedigree  age  label
# 6          3       78  50     32       88  31.0     0.248   26      1
# 10         4      110  92      0        0  37.6     0.191   30      0
# 2          8      183  64      0        0  23.3     0.672   32      1
# 14         5      166  72     19      175  25.8     0.587   51      1
# 4          0      137  40     35      168  43.1     2.288   33      1
# 17         7      107  74      0        0  29.6     0.254   31      1
# 7         10      115   0      0        0  35.3     0.134   29      0
# 1          1       85  66     29        0  26.6     0.351   31      0
# 13         1      189  60     23      846  30.1     0.398   59      1
# 0          6      148  72     35        0  33.6     0.627   50      1
# 19         1      115  70     30       96  34.6     0.529   32      1
# 18         1      103  30     38       83  43.3     0.183   33      0
# 9          8      125  96      0        0   0.0     0.232   54      1
# 15         7      100   0      0        0  30.0     0.484   32      1
# 8          2      197  70     45      543  30.5     0.158   53      1
# 12        10      139  80      0        0  27.1     1.441   57      0
# 11        10      168  74      0        0  38.0     0.537   34      1
# 5          5      116  74      0        0  25.6     0.201   30      0

# %%
feature_columns=['pregnant','insulin','bmi','age','glucose','bp','pedigree']
x=pimax[feature_columns]
y=pimax.label

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
#create decision tree classifier object
clf=DecisionTreeClassifier(criterion="entropy")

# %%
# train decision tree classifier
clf=clf.fit(x_train,y_train)

# %%
#predict the response for the test dataset
y_pred=clf.predict(x_test)
print("Accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.75

# %% [raw]
# from sklearn.tree import export_graphviz
# from six import StringIO
# from IPython.display import Image
# import pydotplus
#
# dot_data = StringIO()
# export_graphviz(clf, out_file=dot_data,
# filled=True, rounded=True,
# special_characters=True,feature_names = feature_columns,class_names=['0','1'])
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# graph.write_png('diabetes.png')
# Image(graph.create_png())

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(clf,filled=True)
# Out:
# [Text(502.20000000000005, 475.65000000000003, 'X[1] <= 85.5\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]'),
#  Text(334.8, 339.75, 'X[0] <= 5.5\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]'),
#  Text(167.4, 203.85000000000002, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(502.20000000000005, 203.85000000000002, 'X[6] <= 1.034\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(334.8, 67.94999999999999, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(669.6, 67.94999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(669.6, 339.75, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]')]

# %%
from platform import python_version
print(python_version())

# %%
pip install graphviz

# %%
import os
os.environ["PATH"]+=os.pathsep+'C:\ProgramData\Anaconda3\Library\bin'

# %%
data

# %% [raw]
#
# from sklearn.tree import export_graphviz
# from six import StringIO
# from IPython.display import Image
# import pydotplus
#
# dot_data = StringIO()
# export_graphviz(clf, out_file=dot_data,
# filled=True, rounded=True,
# special_characters=True,feature_names = feature_columns,class_names=['0','1'])
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# graph.write_png('diabetes.png')
# Image(graph.create_png())
